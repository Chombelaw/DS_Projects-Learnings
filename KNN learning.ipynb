# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Coded_Data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Cd_1  Cd_2  Cd_3  Cd_4  Cd_5  Cd_6  Cd_7  Cd_8  Cd_9  Cd_10  \
# 0           1  53.1  63.4  33.0  46.2  47.3  21.2  44.3  36.1  46.6   65.0
# 1           2  36.9  54.7  31.1  50.5  56.0  38.9  39.4  56.8  33.0   78.8
# 2           3  41.9  65.5  53.5  52.3  92.5  43.2  94.9  64.7  50.8   67.9
# 3           4  71.7  75.6  37.9  50.5  69.2  52.5  82.3  77.3  80.8   60.9
# 4           5  74.3  51.8  36.4  40.9  74.7  42.2  65.1  36.2  77.6   74.9
#
#   Result
# 0      Y
# 1      N
# 2      N
# 3      Y
# 4      Y

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
# Unnamed: 0    1000 non-null int64
# Cd_1          1000 non-null float64
# Cd_2          1000 non-null float64
# Cd_3          1000 non-null float64
# Cd_4          1000 non-null float64
# Cd_5          1000 non-null float64
# Cd_6          1000 non-null float64
# Cd_7          1000 non-null float64
# Cd_8          1000 non-null float64
# Cd_9          1000 non-null float64
# Cd_10         1000 non-null float64
# Result        1000 non-null object
# dtypes: float64(10), int64(1), object(1)
# memory usage: 93.8+ KB

# %%
sns.heatmap(df.isnull())

# %%
sns.countplot(df.Result)

# %%
df['Result'].value_counts()
# Out:
# Y    500
# N    500
# Name: Result, dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0  Cd_1  Cd_2  Cd_3  Cd_4  Cd_5  Cd_6  Cd_7  Cd_8  Cd_9  Cd_10  \
# 0           1  53.1  63.4  33.0  46.2  47.3  21.2  44.3  36.1  46.6   65.0
# 1           2  36.9  54.7  31.1  50.5  56.0  38.9  39.4  56.8  33.0   78.8
# 2           3  41.9  65.5  53.5  52.3  92.5  43.2  94.9  64.7  50.8   67.9
# 3           4  71.7  75.6  37.9  50.5  69.2  52.5  82.3  77.3  80.8   60.9
# 4           5  74.3  51.8  36.4  40.9  74.7  42.2  65.1  36.2  77.6   74.9
#
#   Result
# 0      Y
# 1      N
# 2      N
# 3      Y
# 4      Y

# %%
df= pd.read_csv('Coded_Data.csv',index_col=0)

# %%
df.head()
# Out:
#    Cd_1  Cd_2  Cd_3  Cd_4  Cd_5  Cd_6  Cd_7  Cd_8  Cd_9  Cd_10 Result
# 1  53.1  63.4  33.0  46.2  47.3  21.2  44.3  36.1  46.6   65.0      Y
# 2  36.9  54.7  31.1  50.5  56.0  38.9  39.4  56.8  33.0   78.8      N
# 3  41.9  65.5  53.5  52.3  92.5  43.2  94.9  64.7  50.8   67.9      N
# 4  71.7  75.6  37.9  50.5  69.2  52.5  82.3  77.3  80.8   60.9      Y
# 5  74.3  51.8  36.4  40.9  74.7  42.2  65.1  36.2  77.6   74.9      Y

# %%
sns.pairplot(data = df, hue = 'Result')

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
df.head();

# %%
features = df.drop('Result', axis = 1)

# %%
features.head();

# %%
target = df['Result']

# %%
target.head();

# %%
scaledFeatures = scaler.fit_transform(features)

# %%
type(scaledFeatures)
# Out:
# numpy.ndarray

# %%
col = df.columns[:-1]

# %%
col
# Out:
# Index(['Cd_1', 'Cd_2', 'Cd_3', 'Cd_4', 'Cd_5', 'Cd_6', 'Cd_7', 'Cd_8', 'Cd_9',
#        'Cd_10'],
#       dtype='object')

# %%
scaledFeatures_Df = pd.DataFrame(data=scaledFeatures,  columns=col)

# %%
scaledFeatures_Df.head()
# Out:
#        Cd_1      Cd_2      Cd_3      Cd_4      Cd_5      Cd_6      Cd_7  \
# 0 -0.122525  0.187569 -0.911832  0.318653 -1.035516 -2.305940 -0.801865
# 1 -1.086028 -0.433403 -1.024151  0.624941 -0.445471 -1.153296 -1.131088
# 2 -0.788651  0.337459  0.300034  0.753154  2.030007 -0.873275  2.597862
# 3  0.983718  1.058359 -0.622166  0.624941  0.449771 -0.267648  1.751290
# 4  1.138354 -0.640394 -0.710839 -0.058864  0.822788 -0.938396  0.595651
#
#        Cd_8      Cd_9     Cd_10
# 0 -1.480070 -0.952562 -0.645366
# 1 -0.200556 -1.826218  0.635103
# 2  0.287761 -0.682756 -0.376282
# 3  1.066595  1.244427 -1.025795
# 4 -1.473889  1.038861  0.273232

# %%
X = scaledFeatures_Df

# %%
X.head();

# %%
y = target

# %%
y.head();

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
classifier = KNeighborsClassifier(n_neighbors=12)

# %%
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=12, p=2,
#            weights='uniform')

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import  confusion_matrix,classification_report

# %%
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           N       0.94      0.96      0.95       142
#           Y       0.96      0.95      0.96       158
#
# avg / total       0.95      0.95      0.95       300
#
# [[136   6]
#  [  8 150]]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 700 entries, 541 to 102
# Data columns (total 10 columns):
# Cd_1     700 non-null float64
# Cd_2     700 non-null float64
# Cd_3     700 non-null float64
# Cd_4     700 non-null float64
# Cd_5     700 non-null float64
# Cd_6     700 non-null float64
# Cd_7     700 non-null float64
# Cd_8     700 non-null float64
# Cd_9     700 non-null float64
# Cd_10    700 non-null float64
# dtypes: float64(10)
# memory usage: 60.2 KB

# %%
def elbowmth():
    errorrRate = []
    for k in range(1,31):
        classifier = KNeighborsClassifier(n_neighbors=k)
        classifier.fit(X_train, y_train)
        y_pred = classifier.predict(X_test)       
        errorrRate.append(np.mean(y_pred!=y_test))
    return errorrRate

# %%
errorRate = elbowmth()

# %%
plt.plot(range(1,31),errorRate, color='green',marker='o', markerfacecolor='blue')
